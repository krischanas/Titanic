# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os
import pandas as pd
import seaborn as sns

from scipy.stats.mstats import winsorize
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import PowerTransformer, StandardScaler, MinMaxScaler, QuantileTransformer, RobustScaler
from sklearn.model_selection import train_test_split
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import TransformedTargetRegressor
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import ElasticNet
from xgboost import XGBRegressor

pd.pandas.set_option('display.max_columns', None)

import warnings
warnings.simplefilter(action='ignore')
from pylab import rcParams
rcParams['figure.figsize'] = 10, 7

# %%
project_path = r'C:\Users\kchanas\Documents\Learning\Kaggle\Titanic'
train = pd.read_csv(os.path.join(project_path, r'data\train.csv')).set_index('PassengerId')
test = pd.read_csv(os.path.join(project_path, r'data\test.csv')).set_index('PassengerId')

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
train.shape
test.shape
# Out:
# (891, 11)
# (418, 10)

# %% [markdown]
# ## Extract features from Name, Ticket and Cabin

# %%
def extract_title(name): 
    parts_of_name = name.split()
    parts_of_name = [part for part in parts_of_name if '.' in part]
    return parts_of_name[0]

train['Title'] = train['Name'].apply(extract_title)
test['Title'] = test['Name'].apply(extract_title)

# %%
train['Title'] = np.where(train['Title'].isin(['Mr.','Miss.','Mrs.','Master.']), train['Title'], 'Other')
test['Title'] = np.where(test['Title'].isin(['Mr.','Miss.','Mrs.','Master.']), test['Title'], 'Other')

# %%
def extract_ticket_type(df):
    df = df.copy()
    df['Ticket_number'] = pd.to_numeric(df['Ticket'], errors='coerce')
    df['Ticket_number_str'] = df['Ticket_number'].astype(str)
    df['Ticket_length'] = df['Ticket_number_str'].apply(lambda x: len(x.replace('.0', '')))

    ticket_type = []
    ticket = df['Ticket']
    ticket_number = df['Ticket_number']
    ticket_length = df['Ticket_length']

    for t, t_number, t_length in zip(ticket, ticket_number, ticket_length):
        if t_length > 3:
            t_type = str(t_length) + '-digit'
        else:
            for text in ['A','C','F','L','P','S','SOTON','STON','W']:
                if t.startswith(text):
                    t_type = text
                    break
                else:
                    t_type = 'Other'
        ticket_type.append(t_type)
    return ticket_type

train['Ticket_Type'] = extract_ticket_type(train)
test['Ticket_Type'] = extract_ticket_type(test)

# %%
train['Cabin_Type'] = np.where(train['Cabin'].notnull(), train['Cabin'].str[0], 'NoCabin')
test['Cabin_Type'] = np.where(test['Cabin'].notnull(), test['Cabin'].str[0], 'NoCabin')

# %%
categories_labels = {'Title': ['Mr.','Mrs.','Miss.','Master.'],
                    'Ticket_Type': ['4-digit','5-digit','6-digit','P'],
                    'Cabin_Type': ['NoCabin']}

for var in ['Title','Ticket_Type','Cabin_Type']:
    for df in [train, test]:
        df[var] = np.where(df[var].isin(categories_labels[var]), df[var], 'Other')

# %%
train = train.drop(['Name','Ticket','Cabin'],axis=1)
test = test.drop(['Name','Ticket','Cabin'],axis=1)

# %% [markdown]
# ## Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(train, train['Survived'], test_size=0.3, random_state=1, stratify=train['Survived'])

# %%
X_train.head()
X_train.info()
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  \
# PassengerId
# 473                 1       2  female  33.0      1      2  27.7500        S
# 598                 0       3    male  49.0      0      0   0.0000        S
# 844                 0       3    male  34.5      0      0   6.4375        C
# 113                 0       3    male  22.0      0      0   8.0500        S
# 870                 1       3    male   4.0      1      1  11.1333        S
#
#                Title Ticket_Type Cabin_Type
# PassengerId
# 473             Mrs.       Other    NoCabin
# 598              Mr.       Other    NoCabin
# 844              Mr.     4-digit    NoCabin
# 113              Mr.     6-digit    NoCabin
# 870          Master.     6-digit    NoCabin
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 623 entries, 473 to 465
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
y_train.value_counts(normalize=True)
y_test.value_counts(normalize=True)
# Out:
# 0    0.616372
# 1    0.383628
# Name: Survived, dtype: float64
# 0    0.615672
# 1    0.384328
# Name: Survived, dtype: float64

# %% [markdown]
# ## Variables types

# %%
num_vars = [var for var in X_train.columns if X_train[var].dtypes != 'O' and 'Survived' not in var]
discrete_vars = [var for var in num_vars if X_train[var].nunique() <= 20]
num_vars = [var for var in num_vars if var not in discrete_vars]
cat_vars = [var for var in X_train.columns if X_train[var].dtypes == 'O']

print('Numeric variables: ', num_vars)
print('Discrete variables: ', discrete_vars)
print('Categorical variables: ', cat_vars)
# Out:
# Numeric variables:  ['Age', 'Fare']
# Discrete variables:  ['Pclass', 'SibSp', 'Parch']
# Categorical variables:  ['Sex', 'Embarked', 'Title', 'Ticket_Type', 'Cabin_Type']

# %% [markdown]
# ## Missing values

# %%
cat_vars_with_na = [col for col in cat_vars if (train[col].isnull().sum() > 0) or (test[col].isnull().sum() > 0)]
train[cat_vars_with_na].isnull().mean().sort_values(ascending=False)
print(cat_vars_with_na)
# Out:
# Embarked    0.002245
# dtype: float64
# ['Embarked']

# %%
X_train['Embarked'].isnull().sum()
X_test['Embarked'].isnull().sum()
test['Embarked'].isnull().sum()
# Out:
# 2
# 0
# 0

# %%
print(X_train.shape)
pass_to_delete = X_train[X_train['Embarked'].isnull()].index
y_train = y_train.drop(pass_to_delete, axis=0)
X_train = X_train[~(X_train['Embarked'].isnull())]
print(X_train.shape)
print(y_train.shape)

print(X_test.shape)
pass_to_delete = X_test[X_test['Embarked'].isnull()].index
y_test = y_test.drop(pass_to_delete, axis=0)
X_test = X_test[~(X_test['Embarked'].isnull())]
print(X_test.shape)
print(y_test.shape)
# Out:
# (623, 11)
# (621, 11)
# (621,)
# (268, 11)
# (268, 11)
# (268,)

# %%
num_vars_with_na = [col for col in num_vars if (train[col].isnull().sum() > 0) or (test[col].isnull().sum() > 0)]
print(X_train[num_vars_with_na].isnull().mean().sort_values(ascending=False))
print(X_test[num_vars_with_na].isnull().mean().sort_values(ascending=False))
print(test[num_vars_with_na].isnull().mean().sort_values(ascending=False))
# Out:
# Age     0.196457
# Fare    0.000000
# dtype: float64
# Age     0.205224
# Fare    0.000000
# dtype: float64
# Age     0.205742
# Fare    0.002392
# dtype: float64

# %%
fare_median = X_train['Fare'].median()
X_train['Fare'] = X_train['Fare'].fillna(fare_median)
X_test['Fare'] = X_test['Fare'].fillna(fare_median)
test['Fare'] = test['Fare'].fillna(fare_median)

# %% [markdown]
# X_missing_to_impute = X_train[X_train['Age'].isnull()].drop(['Survived','Age'],axis=1)
# X_test_missing_to_impute = X_test[X_test['Age'].isnull()].drop(['Survived','Age'],axis=1)
# test_missing_to_impute = test[test['Age'].isnull()].drop('Age',axis=1)
# X_missing_to_train = X_train[~(X_train['Age'].isnull())].drop(['Survived','Age'],axis=1)
# y_missing_to_train = X_train[~(X_train['Age'].isnull())]['Age']
#
# X_missing_to_impute = pd.get_dummies(X_missing_to_impute, columns=['Embarked','Sex','Title','Ticket_Type','Cabin_Type'], drop_first=True)
# X_test_missing_to_impute = pd.get_dummies(X_test_missing_to_impute, columns=['Embarked','Sex','Title','Ticket_Type','Cabin_Type'], drop_first=True)
# test_missing_to_impute = pd.get_dummies(test_missing_to_impute, columns=['Embarked','Sex','Title','Ticket_Type','Cabin_Type'], drop_first=True)
# X_missing_to_train = pd.get_dummies(X_missing_to_train, columns=['Embarked','Sex','Title','Ticket_Type','Cabin_Type'], drop_first=True)
#
# X_missing_to_impute.shape
# X_missing_to_train.shape
# X_test_missing_to_impute.shape
# test_missing_to_impute.shape
#
# X_missing_to_impute = X_missing_to_impute.reindex(columns=X_missing_to_train.columns)
# X_test_missing_to_impute = X_test_missing_to_impute.reindex(columns=X_missing_to_train.columns)
# test_missing_to_impute = test_missing_to_impute.reindex(columns=X_missing_to_train.columns)
#
# X_missing_to_impute.shape
# X_missing_to_train.shape
# X_test_missing_to_impute.shape
# test_missing_to_impute.shape
#
# for df in [X_missing_to_impute, X_test_missing_to_impute, test_missing_to_impute, X_missing_to_train]:
#     df['Fare'] = np.log1p(df['Fare'])
#
# X_missing_to_train.head()
#
# pipe_impute = Pipeline([('scaler', StandardScaler()),
#                        ('model', TransformedTargetRegressor(XGBRegressor(n_estimators=300),
#                                                             func = np.log, inverse_func=np.exp))])
# pipe_impute.fit(X_missing_to_train, y_missing_to_train)
#
# preds = pipe_impute.predict(X_missing_to_train)
# rmse = np.sqrt(mean_squared_error(y_missing_to_train, preds))
# rmse
#
# train_imputed = pd.Series(np.round(pipe_impute.predict(X_missing_to_impute), 0), name='Age_Imputed', index=X_missing_to_impute.index)
# X_test_imputed = pd.Series(np.round(pipe_impute.predict(X_test_missing_to_impute), 0), name='Age_Imputed', index=X_test_missing_to_impute.index)
# test_imputed = pd.Series(np.round(pipe_impute.predict(test_missing_to_impute), 0), name='Age_Imputed', index=test_missing_to_impute.index)
#
# X_train = pd.concat([X_train, train_imputed], axis=1)
# X_train['Missing_Age'] = np.where(X_train['Age'].isnull(), 1, 0)
# X_train['Age'] = np.where(X_train['Age'].isnull(), X_train['Age_Imputed'], X_train['Age'])
#
# X_test = pd.concat([X_test, X_test_imputed], axis=1)
# X_test['Missing_Age'] = np.where(X_test['Age'].isnull(), 1, 0)
# X_test['Age'] = np.where(X_test['Age'].isnull(), X_test['Age_Imputed'], X_test['Age'])
#
# test = pd.concat([test, test_imputed], axis=1)
# test['Missing_Age'] = np.where(test['Age'].isnull(), 1, 0)
# test['Age'] = np.where(test['Age'].isnull(), test['Age_Imputed'], test['Age'])
#
# X_train = X_train.drop('Age_Imputed', axis=1)
# X_test = X_test.drop('Age_Imputed', axis=1)
# test = test.drop('Age_Imputed', axis=1)

# %% [markdown]
# For now I will stay with missing values for Age variable. I will create buckets out of this variable and missing values will be one of the buckets.

# %%
print(X_train[num_vars_with_na].isnull().mean().sort_values(ascending=False))
print(X_test[num_vars_with_na].isnull().mean().sort_values(ascending=False))
print(test[num_vars_with_na].isnull().mean().sort_values(ascending=False))
# Out:
# Age     0.196457
# Fare    0.000000
# dtype: float64
# Age     0.205224
# Fare    0.000000
# dtype: float64
# Age     0.205742
# Fare    0.000000
# dtype: float64

# %%
discrete_vars_with_na = [col for col in discrete_vars if (train[col].isnull().sum() > 0) or (test[col].isnull().sum() > 0)]
print(X_train[discrete_vars_with_na].isnull().mean().sort_values(ascending=False))
print(X_test[discrete_vars_with_na].isnull().mean().sort_values(ascending=False))
print(test[discrete_vars_with_na].isnull().mean().sort_values(ascending=False))
# Out:
# Series([], dtype: float64)
# Series([], dtype: float64)
# Series([], dtype: float64)

# %%
[col for col in X_train.columns if X_train[col].isnull().sum() > 0]
[col for col in X_test.columns if X_test[col].isnull().sum() > 0]
[col for col in test.columns if test[col].isnull().sum() > 0]
# Out:
# ['Age']
# ['Age']
# ['Age']

# %%
X_train.head()
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  \
# PassengerId
# 473                 1       2  female  33.0      1      2  27.7500        S
# 598                 0       3    male  49.0      0      0   0.0000        S
# 844                 0       3    male  34.5      0      0   6.4375        C
# 113                 0       3    male  22.0      0      0   8.0500        S
# 870                 1       3    male   4.0      1      1  11.1333        S
#
#                Title Ticket_Type Cabin_Type
# PassengerId
# 473             Mrs.       Other    NoCabin
# 598              Mr.       Other    NoCabin
# 844              Mr.     4-digit    NoCabin
# 113              Mr.     6-digit    NoCabin
# 870          Master.     6-digit    NoCabin

# %% [markdown]
# ## Numerical variables

# %%
for df in [X_train, X_test, test]:
    df['Age_Bucket'] = pd.cut(df['Age'], bins=[0,19,25,32,42,100]).astype(str)
    df['Fare_Bucket'] = pd.cut(df['Fare'], bins=[-0.01,11,46,513]).astype(str)
    df['Age_Bucket'] = np.where(df['Age_Bucket']=='nan', 'Missing', df['Age_Bucket'])
    df['Fare_Bucket'] = np.where(df['Fare_Bucket']=='nan', 'Missing', df['Fare_Bucket'])

# %%
X_train['Fare_Bucket'].value_counts()
# Out:
# (-0.01, 11.0]    254
# (11.0, 46.0]     242
# (46.0, 513.0]    125
# Name: Fare_Bucket, dtype: int64

# %%
    
age_mapping = {'Missing': 'Missing',
               '(0.0, 19.0]': '0-19',
              '(19.0, 25.0]': '19-25',
              '(25.0, 32.0]': '25-32',
              '(32.0, 42.0]': '32-42',
              '(42.0, 100.0]': '42-100'}

fare_mapping = {'(-0.01, 11.0]': '0-11',
               '(11.0, 46.0]': '11-46',
               '(46.0, 513.0]': '>46'}

for df in [X_train, X_test, test]:
    df['Age_Bucket'] = df['Age_Bucket'].astype(str).map(age_mapping)
    df['Fare_Bucket'] = df['Fare_Bucket'].astype(str).map(fare_mapping)

# %%
X_train['Age_Bucket'].isnull().sum()
X_train['Fare_Bucket'].isnull().sum()
# Out:
# 0
# 0

# %%
X_train = X_train.drop(['Age','Fare'], axis=1)
X_test = X_test.drop(['Age','Fare'], axis=1)
test = test.drop(['Age','Fare'], axis=1)

# %% [markdown]
# pt = PowerTransformer()
# X_train[num_vars] = pt.fit_transform(X_train[num_vars])
# X_test[num_vars] = pt.transform(X_test[num_vars])
# test[num_vars] = pt.transform(test[num_vars])
#
# #X_train[num_vars] = np.log1p(X_train[num_vars])
# #X_test[num_vars] = np.log1p(X_test[num_vars])
# #test[num_vars] = np.log1p(test[num_vars])

# %%
X_train.head()
# Out:
#              Survived  Pclass     Sex  SibSp  Parch Embarked    Title  \
# PassengerId
# 473                 1       2  female      1      2        S     Mrs.
# 598                 0       3    male      0      0        S      Mr.
# 844                 0       3    male      0      0        C      Mr.
# 113                 0       3    male      0      0        S      Mr.
# 870                 1       3    male      1      1        S  Master.
#
#             Ticket_Type Cabin_Type Age_Bucket Fare_Bucket
# PassengerId
# 473               Other    NoCabin      32-42       11-46
# 598               Other    NoCabin     42-100        0-11
# 844             4-digit    NoCabin      32-42        0-11
# 113             6-digit    NoCabin      19-25        0-11
# 870             6-digit    NoCabin       0-19       11-46

# %%
cat_vars = cat_vars + ['Age_Bucket','Fare_Bucket']

# %% [markdown]
# ## Discrete variables

# %%
for df in [X_train, X_test, test]:
    df['SibSp_'] = np.where(df['SibSp']>=2, '2>=', df['SibSp'])
    df['Parch_'] = np.where(df['Parch']>=2, '2>=', df['Parch'])
    df['SibSp'] = df['SibSp_'].copy()
    df['Parch'] = df['Parch_'].copy()

X_train = X_train.drop(['SibSp_','Parch_'], axis=1)
X_test = X_test.drop(['SibSp_','Parch_'], axis=1)
test = test.drop(['SibSp_','Parch_'], axis=1)
X_train.head()
# Out:
#              Survived  Pclass     Sex SibSp Parch Embarked    Title  \
# PassengerId
# 473                 1       2  female     1   2>=        S     Mrs.
# 598                 0       3    male     0     0        S      Mr.
# 844                 0       3    male     0     0        C      Mr.
# 113                 0       3    male     0     0        S      Mr.
# 870                 1       3    male     1     1        S  Master.
#
#             Ticket_Type Cabin_Type Age_Bucket Fare_Bucket
# PassengerId
# 473               Other    NoCabin      32-42       11-46
# 598               Other    NoCabin     42-100        0-11
# 844             4-digit    NoCabin      32-42        0-11
# 113             6-digit    NoCabin      19-25        0-11
# 870             6-digit    NoCabin       0-19       11-46

# %%
cat_vars = cat_vars + ['SibSp','Parch']

# %%
X_test.to_csv(os.path.join(project_path, r'sandbox\X_test_before_encoding.csv'))

# %% [markdown]
# # Encode categorical variables

# %%
vars_to_encode = cat_vars + ['Pclass']

# %%
def encode_categories(train, test, test_lb, var):
    ordered_categories = train.groupby(var)['Survived'].mean().sort_values().index
    train.groupby(var)['Survived'].mean().sort_values(ascending=True).plot.bar()
    plt.show()
    ordered_labels = {k: i for i, k in enumerate(ordered_categories, 0)}
    train[var + '_enc'] = train[var].map(ordered_labels)
    test[var + '_enc'] = test[var].map(ordered_labels)
    test[var + '_enc'] = test[var + '_enc'].fillna(train[var + '_enc'].mode().iloc[0])
    test_lb[var + '_enc'] = test_lb[var].map(ordered_labels)
    test_lb[var + '_enc'] = test_lb[var + '_enc'].fillna(train[var + '_enc'].mode().iloc[0])
    
      
for var in vars_to_encode:
    encode_categories(X_train, X_test, test, var)

# %%
X_train.head()
# Out:
#              Survived  Pclass     Sex SibSp Parch Embarked    Title  \
# PassengerId
# 473                 1       2  female     1   2>=        S     Mrs.
# 598                 0       3    male     0     0        S      Mr.
# 844                 0       3    male     0     0        C      Mr.
# 113                 0       3    male     0     0        S      Mr.
# 870                 1       3    male     1     1        S  Master.
#
#             Ticket_Type Cabin_Type Age_Bucket Fare_Bucket  Sex_enc  \
# PassengerId
# 473               Other    NoCabin      32-42       11-46        1
# 598               Other    NoCabin     42-100        0-11        0
# 844             4-digit    NoCabin      32-42        0-11        0
# 113             6-digit    NoCabin      19-25        0-11        0
# 870             6-digit    NoCabin       0-19       11-46        0
#
#              Embarked_enc  Title_enc  Ticket_Type_enc  Cabin_Type_enc  \
# PassengerId
# ...

# %%
def encode_categories_with_median_target(train, test, test_lb, var):
    ordered_categories = train.groupby(var)['Survived'].mean().sort_values()
    train.groupby(var)['Survived'].mean().sort_values(ascending=True).plot.bar()
    plt.show()
    ordered_labels = ordered_categories.to_dict()
    print(ordered_labels)
   
    train[var + '_enc_%'] = train[var].map(ordered_labels)
    test[var + '_enc_%'] = test[var].map(ordered_labels)
    test[var + '_enc_%'] = test[var + '_enc_%'].fillna(train[var].mode().iloc[0])
    test_lb[var + '_enc_%'] = test_lb[var].map(ordered_labels)
    test_lb[var + '_enc_%'] = test_lb[var + '_enc_%'].fillna(train[var].mode().iloc[0])

for var in vars_to_encode:
    encode_categories_with_median_target(X_train, X_test, test, var)
# Out:
# {'male': 0.1935483870967742, 'female': 0.7293577981651376}
# {'S': 0.3355408388520971, 'Q': 0.39215686274509803, 'C': 0.5555555555555556}
# {'Mr.': 0.16066481994459833, 'Other': 0.47058823529411764, 'Master.': 0.5806451612903226, 'Miss.': 0.6910569105691057, 'Mrs.': 0.7640449438202247}
# {'Other': 0.2631578947368421, '6-digit': 0.33212996389891697, '4-digit': 0.3472222222222222, '5-digit': 0.5882352941176471, 'P': 0.6756756756756757}
# {'NoCabin': 0.28662420382165604, 'Other': 0.68}
# {'19-25': 0.3225806451612903, 'Missing': 0.32786885245901637, '42-100': 0.3372093023255814, '25-32': 0.39603960396039606, '32-42': 0.40594059405940597, '0-19': 0.4830508474576271}
# {'0-11': 0.21653543307086615, '11-46': 0.4256198347107438, '>46': 0.632}
# {'2>=': 0.22641509433962265, '0': 0.3523809523809524, '1': 0.5202702702702703}
# {'0': 0.34334763948497854, '2>=': 0.4411764705882353, '1': 0.5402298850574713}
# {3: 0.23919308357348704, 2: 0.4634146341463415, 1: 0.6423841059602649}

# %%
X_train.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked', 'Title',
#        'Ticket_Type', 'Cabin_Type', 'Age_Bucket', 'Fare_Bucket', 'Sex_enc',
#        'Embarked_enc', 'Title_enc', 'Ticket_Type_enc', 'Cabin_Type_enc',
#        'Age_Bucket_enc', 'Fare_Bucket_enc', 'SibSp_enc', 'Parch_enc',
#        'Pclass_enc', 'Sex_enc_%', 'Embarked_enc_%', 'Title_enc_%',
#        'Ticket_Type_enc_%', 'Cabin_Type_enc_%', 'Age_Bucket_enc_%',
#        'Fare_Bucket_enc_%', 'SibSp_enc_%', 'Parch_enc_%', 'Pclass_enc_%'],
#       dtype='object')

# %%
vars_to_dummy = ['Pclass','Sex', 'Embarked', 'Title', 'Ticket_Type', 'Cabin_Type', 'SibSp', 'Parch', 'Age_Bucket', 'Fare_Bucket']

# %%
X_train = pd.get_dummies(X_train, columns=vars_to_dummy, drop_first=True)
X_test = pd.get_dummies(X_test, columns=vars_to_dummy, drop_first=True)
test = pd.get_dummies(test, columns=vars_to_dummy, drop_first=True)

# %%
X_train.head()
# Out:
#              Survived  Sex_enc  Embarked_enc  Title_enc  Ticket_Type_enc  \
# PassengerId
# 473                 1        1             0          4                0
# 598                 0        0             0          0                0
# 844                 0        0             2          0                2
# 113                 0        0             0          0                1
# 870                 1        0             0          2                1
#
#              Cabin_Type_enc  Age_Bucket_enc  Fare_Bucket_enc  SibSp_enc  \
# PassengerId
# 473                       0               4                1          2
# 598                       0               2                0          1
# 844                       0               4                0          1
# 113                       0               0                0          1
# 870                       0               5                1          2
#
# ...

# %%
X_test.head()
# Out:
#              Survived  Sex_enc  Embarked_enc  Title_enc  Ticket_Type_enc  \
# PassengerId
# 434                 0        0             0          0                0
# 222                 0        0             0          0                1
# 218                 0        0             0          0                1
# 377                 1        1             0          3                0
# 448                 1        0             0          0                1
#
#              Cabin_Type_enc  Age_Bucket_enc  Fare_Bucket_enc  SibSp_enc  \
# PassengerId
# 434                       0               5                0          1
# 222                       0               3                1          1
# 218                       0               4                1          2
# 377                       0               0                0          1
# 448                       0               4                1          1
#
# ...

# %%
test.head()
# Out:
#              Sex_enc  Embarked_enc  Title_enc  Ticket_Type_enc  \
# PassengerId
# 892                0             1          0                1
# 893                1             0          4                1
# 894                0             1          0                1
# 895                0             0          0                1
# 896                1             0          4                0
#
#              Cabin_Type_enc  Age_Bucket_enc  Fare_Bucket_enc  SibSp_enc  \
# PassengerId
# 892                       0               4                0          1
# 893                       0               2                0          2
# 894                       0               2                0          1
# 895                       0               3                0          1
# 896                       0               0                1          2
#
#              Parch_enc  Pclass_enc  Sex_enc_%  Embarked_enc_%  Title_enc_%  \
# PassengerId
# ...

# %%
X_train.shape
X_test.shape
test.shape
# Out:
# (621, 46)
# (268, 46)
# (418, 45)

# %%
X_train.isnull().sum().sum()
X_test.isnull().sum().sum()
test.isnull().sum().sum()
# Out:
# 0
# 0
# 0

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 621 entries, 473 to 465
# Data columns (total 46 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Survived             621 non-null    int64
#  1   Sex_enc              621 non-null    int64
#  2   Embarked_enc         621 non-null    int64
#  3   Title_enc            621 non-null    int64
#  4   Ticket_Type_enc      621 non-null    int64
#  5   Cabin_Type_enc       621 non-null    int64
#  6   Age_Bucket_enc       621 non-null    int64
#  7   Fare_Bucket_enc      621 non-null    int64
#  8   SibSp_enc            621 non-null    int64
#  9   Parch_enc            621 non-null    int64
#  10  Pclass_enc           621 non-null    int64
#  11  Sex_enc_%            621 non-null    float64
#  12  Embarked_enc_%       621 non-null    float64
#  13  Title_enc_%          621 non-null    float64
#  14  Ticket_Type_enc_%    621 non-null    float64
# ...

# %%
X_train.columns
# Out:
# Index(['Survived', 'Sex_enc', 'Embarked_enc', 'Title_enc', 'Ticket_Type_enc',
#        'Cabin_Type_enc', 'Age_Bucket_enc', 'Fare_Bucket_enc', 'SibSp_enc',
#        'Parch_enc', 'Pclass_enc', 'Sex_enc_%', 'Embarked_enc_%', 'Title_enc_%',
#        'Ticket_Type_enc_%', 'Cabin_Type_enc_%', 'Age_Bucket_enc_%',
#        'Fare_Bucket_enc_%', 'SibSp_enc_%', 'Parch_enc_%', 'Pclass_enc_%',
#        'Pclass_2', 'Pclass_3', 'Sex_male', 'Embarked_Q', 'Embarked_S',
#        'Title_Miss.', 'Title_Mr.', 'Title_Mrs.', 'Title_Other',
#        'Ticket_Type_5-digit', 'Ticket_Type_6-digit', 'Ticket_Type_Other',
#        'Ticket_Type_P', 'Cabin_Type_Other', 'SibSp_1', 'SibSp_2>=', 'Parch_1',
#        'Parch_2>=', 'Age_Bucket_19-25', 'Age_Bucket_25-32', 'Age_Bucket_32-42',
#        'Age_Bucket_42-100', 'Age_Bucket_Missing', 'Fare_Bucket_11-46',
#        'Fare_Bucket_>46'],
#       dtype='object')

# %% [markdown]
# ## Feature scaling

# %%
features_to_scale = ['Embarked_enc', 'Title_enc', 'Ticket_Type_enc', 'Cabin_Type_enc',
       'Pclass_enc', 'Sex_enc_%', 'Embarked_enc_%', 'Title_enc_%',
       'Ticket_Type_enc_%', 'Cabin_Type_enc_%', 'Pclass_enc_%','Age_Bucket_enc', 'Fare_Bucket_enc','Age_Bucket_enc_%',
       'Fare_Bucket_enc_%']

ss = StandardScaler()

X_train = X_train.drop('Survived', axis=1)
X_test = X_test.drop('Survived', axis=1)

#X_train = pd.DataFrame(ss.fit_transform(X_train), columns = X_train.columns, index = X_train.index)
#X_test = pd.DataFrame(ss.transform(X_test), columns = X_test.columns, index = X_test.index)
#test = pd.DataFrame(ss.transform(test), columns=test.columns, index = test.index)

X_train[features_to_scale] = ss.fit_transform(X_train[features_to_scale])
X_test[features_to_scale] = ss.transform(X_test[features_to_scale])
test[features_to_scale] = ss.transform(test[features_to_scale])
X_train.head()
X_test.head()
test.head()
# Out:
#              Sex_enc  Embarked_enc  Title_enc  Ticket_Type_enc  \
# PassengerId
# 473                1     -0.580456   1.669271        -1.209979
# 598                0     -0.580456  -0.798865        -1.209979
# 844                0      1.949112  -0.798865         0.507500
# 113                0     -0.580456  -0.798865        -0.351240
# 870                0     -0.580456   0.435203        -0.351240
#
#              Cabin_Type_enc  Age_Bucket_enc  Fare_Bucket_enc  SibSp_enc  \
# PassengerId
# 473               -0.564333        0.829817         0.275834          2
# 598               -0.564333       -0.324307        -1.052017          1
# 844               -0.564333        0.829817        -1.052017          1
# 113               -0.564333       -1.478430        -1.052017          1
# 870               -0.564333        1.406879         0.275834          2
#
#              Parch_enc  Pclass_enc  Sex_enc_%  Embarked_enc_%  Title_enc_%  \
# PassengerId
# ...

# %%
X_train.to_csv(os.path.join(project_path, r'data\X_train.csv'))
X_test.to_csv(os.path.join(project_path, r'data\X_test.csv'))
y_train.to_csv(os.path.join(project_path, r'data\y_train.csv'))
y_test.to_csv(os.path.join(project_path, r'data\y_test.csv'))
test.to_csv(os.path.join(project_path, r'data\test_lb.csv'))
